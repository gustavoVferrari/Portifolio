# %%
import sys
sys.path.append(r'C:\Users\gustavo\Documents\Data Science\08-GitHub\Portifolio/Classification')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
from collections import Counter

plt.style.use('ggplot')

# %%
from utils.graphs import plot_categorical_data, plot_numerical_data

# %% [markdown]
# # Read Dataset

# %%
file = r'C:\Users\gustavo\Documents\Data Science\08-GitHub\Portifolio\Classification\titanic\dados_titanic\processed\train.parquet'

df = pd.read_parquet(file)

# %%
print(f'Dataset rows and columns: {df.shape}')
# Out:
# Dataset rows and columns: (891, 16)

# %%
# Selecionando as variáveis categóricas

cat_var = df.select_dtypes(include=['category','object', 'bool']).columns
cat_var
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Ticket', 'Cabin', 'Embarked',
#        'Ticket_1p', 'Cabin_1p', 'Embarked_mod', 'SibSp_mod'],
#       dtype='object')

# %%
num_var = df.select_dtypes(include=['number']).columns
num_var
# Out:
# Index(['PassengerId', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %% [markdown]
# # Check target - Y_true

# %%
# verificar quantidade de labels por target

df['Survived'].value_counts().plot.bar()
plt.title('Target Label - Survived x Not Survived')
plt.legend()
plt.show()

# %% [markdown]
# # Exploratory Analisys

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PassengerId   891 non-null    int64
#  1   Survived      891 non-null    object
#  2   Pclass        891 non-null    object
#  3   Name          891 non-null    object
#  4   Sex           891 non-null    object
#  5   Age           714 non-null    float64
#  6   SibSp         891 non-null    float64
#  7   Parch         891 non-null    float64
#  8   Ticket        891 non-null    object
#  9   Fare          891 non-null    float64
#  10  Cabin         204 non-null    object
#  11  Embarked      889 non-null    object
#  12  Ticket_1p     891 non-null    object
#  13  Cabin_1p      204 non-null    object
#  14  Embarked_mod  889 non-null    object
#  15  SibSp_mod     891 non-null    object
# dtypes: float64(4), int64(1), object(11)
# memory usage: 111.5+ KB

# %% [markdown]
# # Check NA values

# %%
df.isna().mean().plot.bar(figsize=(8,4))
# Out:
# <Axes: >

# %% [markdown]
# # Check Cardinality

# %%
for col in cat_var:
    print('labels por variável: ' + col + ' ' + str(df[col].nunique()))
# Out:
# labels por variável: Survived 2
# labels por variável: Pclass 3
# labels por variável: Name 891
# labels por variável: Sex 2
# labels por variável: Ticket 681
# labels por variável: Cabin 147
# labels por variável: Embarked 3
# labels por variável: Ticket_1p 16
# labels por variável: Cabin_1p 8
# labels por variável: Embarked_mod 2
# labels por variável: SibSp_mod 2

# %%
for col in num_var:
    print('Numero de labels por variável na coluna: ' + col + ' ' + str(df[col].nunique()))
# Out:
# Numero de labels por variável na coluna: PassengerId 891
# Numero de labels por variável na coluna: Age 88
# Numero de labels por variável na coluna: SibSp 7
# Numero de labels por variável na coluna: Parch 7
# Numero de labels por variável na coluna: Fare 248

# %% [markdown]
# # Drop constant features

# %% [markdown]
# # nao tem variável constante

# %% [markdown]
# # Drop Features

# %%
df.drop(columns=['PassengerId', 'Name'], inplace=True) # variável sem valor de predicao

# %%
# renew dtype
num_var = df.select_dtypes(include=['number']).columns
cat_var = df.select_dtypes(include=['object', 'category', 'bool']).columns

# %% [markdown]
# # Graphs

# %%
plot_categorical_data(df=df, target="Survived")

# %%
plot_numerical_data(df, target="Survived")
