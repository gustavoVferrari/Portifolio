# %%
import sys
sys.path.append(r'C:\Users\gustavo\Documents\Data Science\08-GitHub\Portifolio\Classification\dsa\dsa_single_model')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
from utils.graphs import plot_numerical_data

# %% [markdown]
# # Read Dataset

# %%
file = r'C:\Users\gustavo\Documents\Data Science\08-GitHub\Portifolio\Classification\dsa\raw\dataset_treino.csv'

df = pd.read_csv(file)

# %%
df
# Out:
#       id  num_gestacoes  glicose  pressao_sanguinea  grossura_pele  insulina  \
# 0      1              6      148                 72             35         0
# 1      2              1       85                 66             29         0
# 2      3              8      183                 64              0         0
# 3      4              1       89                 66             23        94
# 4      5              0      137                 40             35       168
# ..   ...            ...      ...                ...            ...       ...
# 595  596              0      188                 82             14       185
# 596  597              0       67                 76              0         0
# 597  598              1       89                 24             19        25
# 598  599              1      173                 74              0         0
# 599  600              1      109                 38             18       120
#
#       bmi  indice_historico  idade  classe
# 0    33.6             0.627     50       1
# 1    26.6             0.351     31       0
# 2    23.3             0.672     32       1
# 3    28.1             0.167     21       0
# 4    43.1             2.288     33       1
# ..    ...               ...    ...     ...
# 595  32.0             0.682     22       1
# 596  45.3             0.194     46       0
# 597  27.8             0.559     21       0
# 598  36.8             0.088     38       1
# 599  23.1             0.407     26       0
#
# [600 rows x 10 columns]

# %%
# Selecionando as variáveis categóricas
cat_var = df.select_dtypes(include=['category','object', 'bool']).columns
cat_var
# Out:
# Index([], dtype='object')

# %%
num_var = df.select_dtypes(include=['number']).columns
num_var
# Out:
# Index(['id', 'num_gestacoes', 'glicose', 'pressao_sanguinea', 'grossura_pele',
#        'insulina', 'bmi', 'indice_historico', 'idade', 'classe'],
#       dtype='object')

# %% [markdown]
# # Check target - Y_true

# %%
# verificar quantidade de labels por target
df['classe'].value_counts().plot.bar()
plt.title('Target Label - 0 x 1')
plt.legend()
plt.show()

# %% [markdown]
# # Exploratory Analisys

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 600 non-null    int64
#  1   num_gestacoes      600 non-null    int64
#  2   glicose            600 non-null    int64
#  3   pressao_sanguinea  600 non-null    int64
#  4   grossura_pele      600 non-null    int64
#  5   insulina           600 non-null    int64
#  6   bmi                600 non-null    float64
#  7   indice_historico   600 non-null    float64
#  8   idade              600 non-null    int64
#  9   classe             600 non-null    int64
# dtypes: float64(2), int64(8)
# memory usage: 47.0 KB

# %% [markdown]
# # Check NA values

# %%
df.isna().mean().plot.bar(figsize=(8,4))
# Out:
# <Axes: >

# %% [markdown]
# # Check Cardinality

# %%
for col in cat_var:
    print('labels por variável: ' + col + ' ' + str(df[col].nunique()))

# %%
for col in num_var:
    print('Numero de labels por variável na coluna: ' + col + ' ' + str(df[col].nunique()))
# Out:
# Numero de labels por variável na coluna: id 600
# Numero de labels por variável na coluna: num_gestacoes 17
# Numero de labels por variável na coluna: glicose 129
# Numero de labels por variável na coluna: pressao_sanguinea 45
# Numero de labels por variável na coluna: grossura_pele 51
# Numero de labels por variável na coluna: insulina 164
# Numero de labels por variável na coluna: bmi 233
# Numero de labels por variável na coluna: indice_historico 437
# Numero de labels por variável na coluna: idade 50
# Numero de labels por variável na coluna: classe 2

# %% [markdown]
# # Drop constant features

# %% [markdown]
# # nao tem variável constante

# %%
# renew dtype
num_var = df.select_dtypes(include=['number']).columns
cat_var = df.select_dtypes(include=['object', 'category', 'bool']).columns

# %% [markdown]
# # Graphs

# %%
plot_numerical_data(df, target="classe")
# Out:
# C:\Users\gustavo\Documents\Data Science\08-GitHub\Portifolio\Classification\dsa\dsa_single_model\utils\graphs.py:61: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(

# %%
plot_numerical_data(df, target="classe")
# Out:
# C:\Users\gustavo\Documents\Data Science\08-GitHub\Portifolio\Classification\dsa\dsa_single_model\utils\graphs.py:61: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
